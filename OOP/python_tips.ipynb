# %% [markdown]
# # list comprehension

# %%
squares = [x**2 for x in range(5)]
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %%
names = ["apple", "fruit", "water-melon"]
for i, name in enumerate(names):
    print(i, name)
# Out:
# 0 apple
# 1 fruit
# 2 water-melon
